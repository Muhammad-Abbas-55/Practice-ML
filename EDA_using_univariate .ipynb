# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('datasets/train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from ydata_profiling import ProfileReport
import pandas as pd

df = pd.read_csv('datasets/train.csv')

profile = ProfileReport(df)

profile.to_file(output_file='output.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 77.17it/s]

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## a. Countplot

# %%
sns.countplot(x='Embarked', data=df)
# df['Survived'].value_counts().plot(kind='bar')


# or using pandas
# df['Survived'].value_counts()
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ## b. PieChart

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %% [markdown]
# <div style="border-top:black 2px solid"></div>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
import matplotlib.pyplot as plt
# plt.hist(df['Age'],bins=5)
# sns.histplot(df['Age'],bins=5)

# %% [markdown]
# ## b. Distplot

# %%
sns.distplot(df['Age'],bins=50)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26904\200580271.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],bins=50)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## c. Boxplot

# %%
# Univariate Analysis
# sns.boxplot(df['Age'])      # use to find outlies or noise in data
#or
# sns.boxplot(x='Age', data=df)
# sns.barplot(df['Age'])
# sns.scatterplot(df['Age'])

# Bivariate Analysis 
# sns.barplot(x='Age', y='SibSp', data=df)
# sns.scatterplot(x='Age', y='SibSp', data=df)
# sns.scatterplot(x='Age', y='SibSp', hue='Sex', style='Survived', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='SibSp'>

# %%
df['Age'].min()
# Out:
# np.float64(0.42)

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)
