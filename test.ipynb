# %%
list = [8,100,12,56,7,56,4]
print(list)
# Out:
# [8, 100, 12, 56, 7, 56, 4]

# %%
import sys
print(sys.executable)
# Out:
# e:\My Projects\Python\practice\venv\Scripts\python.exe

# %%
from langgraph.graph import StateGraph
print("working")
# Out:
# working

# %%
import langgraph
import langchain

print("OK")
# Out:
# OK
